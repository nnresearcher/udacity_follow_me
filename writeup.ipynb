# %% [markdown]
# # Writeup

# %% [markdown]
# my github link:https://github.com/nnresearcher

# %% [markdown]
# four projects in here
# ![1111.png](attachment:1111.png)

# %% [markdown]
# ## recipes
# recipes is the practice of some food.
#
# cake-recipe , chili-recipe and forsting-recipe

# %% [markdown]
# README.md
# ![readme-recipe.png](attachment:readme-recipe.png)
# the readme.md just briefly describe the content of the document

# %% [markdown]
# ## Redundant-manipulator
# these project is private projects ,Redundant manipulator inverse movement,the methed is failed, so I'm not going to the public, will be set to private documents
# ![red.png](attachment:red.png)

# %% [markdown]
# Also, I am not here described in detail the content of the document and the usage and environment and other details

# %% [markdown]
# ![11.png](attachment:11.png)

# %% [markdown]
# ## RoboND-Rover-Project
#
# Uadatiy's first project for students RoboND-Rover-Project students should complet decision.py

# %% [markdown]
# ![22.png](attachment:22.png)

# %% [markdown]
# The README.md provided by udacity
# ![223.png](attachment:223.png)

# %% [markdown]
# ## Kinematics-Project
# It does not complet,it is use for udacity's students.It is RoboND-Kinematics-Project
# ![333.png](attachment:333.png)

# %% [markdown]
# The README.md is provided by udacity too
# ![444.png](attachment:444.png)

# %% [markdown]
# my commit graph:
# ![5676.png](attachment:5676.png)
